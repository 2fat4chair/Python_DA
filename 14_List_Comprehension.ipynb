# %% [markdown]
# List Comprehension
#
# ---

# %%
numbers = [x for x in range(100)]

# %%
letters = [x for x in 'PYTHON']

letters
# Out:
# ['P', 'Y', 'T', 'H', 'O', 'N']

# %%
analyst_list = []
job_list = ['Data Analyst Junior', 'Data Engineer']

for job in job_list:
    if "Data Analyst" in job:
        analyst_list.append(job)

# %%
analyst_list = [job for job in job_list]

# %%
analyst_list
# Out:
# ['Data Analyst Junior', 'Data Engineer']

# %%
qualified_roles = []

#for roles in job_roles:
#    for skills in roles['skills']:
#        print(skills)

for job in job_roles:
    qualified = True

    for skill in my_skills:
        if skill not in job['skills']:
            qualified = False
            break
    if qualified:
        qualified_roles.append(job['role'])

qualified_roles
