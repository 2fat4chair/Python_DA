# %% [markdown]
# # 🎬 Exercise: Movie Night Recommender
#
# You have a list of movies. Each movie has a **title** and a list of **genres**.
#
# You also have a list of your **favorite genres**.
#
# ### Your Task:
# Find all movies where **ALL of your favorite genres** are in that movie's genre list.
#
# ### Techniques to use:
# - `for` loop (nested)
# - `not in`
# - `break`
# - Boolean flag (`qualified = True / False`)
# - `.append()`
#
# ### Expected output:
# ```python
# ['The Dark Knight', 'Inception', 'The Batman']
# ```

# %%
# Here is the data - DO NOT CHANGE THIS CELL

movies = [
    {'title': 'The Dark Knight', 'genres': ['Action', 'Crime', 'Drama', 'Thriller']},
    {'title': 'Titanic', 'genres': ['Romance', 'Drama']},
    {'title': 'Inception', 'genres': ['Action', 'Sci-Fi', 'Thriller']},
    {'title': 'The Notebook', 'genres': ['Romance', 'Drama']},
    {'title': 'John Wick', 'genres': ['Action', 'Crime']},
    {'title': 'Interstellar', 'genres': ['Sci-Fi', 'Drama', 'Adventure']},
    {'title': 'Avengers', 'genres': ['Action', 'Sci-Fi', 'Adventure']},
    {'title': 'The Batman', 'genres': ['Action', 'Crime', 'Drama', 'Thriller']},
    {'title': 'Frozen', 'genres': ['Animation', 'Adventure', 'Comedy']},
    {'title': 'Joker', 'genres': ['Crime', 'Drama', 'Thriller']}
]

# Your favorite genres
my_genres = ['Action', 'Thriller']

# %%
# YOUR CODE BELOW - Find movies that match ALL of your favorite genres

# %% [markdown]
# ### 🎯 Bonus Challenge (optional)
#
# Try changing `my_genres` to different values and predict the result BEFORE running:
#
# 1. `my_genres = ['Romance', 'Drama']` → Which movies match?
# 2. `my_genres = ['Sci-Fi']` → Which movies match?
# 3. `my_genres = ['Animation']` → Which movies match?
