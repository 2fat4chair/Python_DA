# %% [markdown]
# SETS (Designed for unique items, unordered)

# %%
job_skills = {'tableu', 'sql', 'python', 'statistics'}

# %%
job_skills
# Out:
# {'python', 'sql', 'statistics', 'tableu'}

# %%
job_skills.add('looker')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableu'}

# %%
job_skills.add('sql')

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableu'}

# %% [markdown]
# Remove

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics', 'tableu'}

# %%
job_skills.remove('tableu')

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics'}

# %% [markdown]
# To find unique stuff from a LIST for example, turn it into SET

# %%
skill_list = ["Python", "R", "SQL", "Tableau", "PowerBI", "Excel", "Tableau"]

# %%
list(set(skill_list))
# Out:
# ['SQL', 'Excel', 'R', 'PowerBI', 'Tableau', 'Python']
