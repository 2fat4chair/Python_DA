# %% [markdown]
# Tuples (....)

# %%
lukes_skill = ('SQL', 'Excel','Python')

lukes_skill
# Out:
# ('SQL', 'Excel', 'Python')

# %%
lukes_skill[0:2]
# Out:
# ('SQL', 'Excel')

# %%
lukes_skill = ('SQL', 'Excel','Python')

new_skill = ('Excel', 'Power BI')

lukes_skill += new_skill

lukes_skill
# Out:
# ('SQL', 'Excel', 'Python', 'Excel', 'Power BI')
